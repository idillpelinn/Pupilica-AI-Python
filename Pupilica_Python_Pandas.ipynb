# %% [markdown]
# <a href="https://colab.research.google.com/github/idillpelinn/Pupilica-AI-Python/blob/main/Pupilica_Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***PANDAS***
#
# * .csv, .txt bunlarin import edilmesi icin kullanılır.
# * Preprocessing : Verinin eğitime hazır hale getirlimesi için veri işleme öncesi işlemleri tanımlar
# * EDA(Exploratory Data Analysis - Keşifsel Veri Analizi) : outlier tespiti , feature, extraction , correlation...
# * Pandas, Series ve DataFrame adlı iki temel veri yapısınu sunar. Series tek boyutlu etiketli veri dizisidir. DataFrame ise iki boyutlu etiketli veri tablosudur.  Bu yapılar verileri düzenli ve erişilebilir şekilde saklamak için kullanılır .
# * Eksik verileri doldurma , verileri filtreleme , verileri sıralama verileri gruplama , verileri birleştirme gibi işlemleri gerçekleştirmek için fonksiyonlar sağlar. Verileri analiz için hazır hale getirmek için kullanılır.
# * Veri görselleştirmek için temel grafikler oluşturma yeteneği sağlar. Bu verileri daha anlaşılır hale getirmek için kullanılır.

# %%
#Pandas kütüphanesini kullanmak için import etmeliyiz.
import pandas as pd
import numpy as np

# %%
#DataFrame : dictionary tipinde değişken alır.
person_list = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, np.nan , 66],
              "maas": [100.0, 150.0, 240.0, 350.0, 110.0, 220.0]}
person_list
# Out:
# {'isim': ['ali', 'veli', 'kenan', 'murat', 'ayse', 'hilal'],
#  'yas': [15, 16, 17, 33, nan, 66],
#  'maas': [100.0, 150.0, 240.0, 350.0, 110.0, 220.0]}

# %%
veri = pd.DataFrame(person_list)
veri
# Out:
#     isim   yas   maas
# 0    ali  15.0  100.0
# 1   veli  16.0  150.0
# 2  kenan  17.0  240.0
# 3  murat  33.0  350.0
# 4   ayse   NaN  110.0
# 5  hilal  66.0  220.0

# %%
#head() : verinin ilk 5 satırını verir.
#tail() : verinin son  satırını verir
"""
Neden biz ilk 5 ve son 5 satıra bakmaya ihtiyaç duyarız ?
1- Veri setinin yapısını ve içeriğini hızlıca anlamak için kullanılır.
2- Veri yükleme veya işleme adımlarından sonra, head() ve tail() ile verilerin beklendiği gibi olup olmadığını kontrol edebiliriz.
"""
#default olarak 5 ancak biz bunu değiştirebiliriz. veri.head(10)
veri.head()
veri.tail()
# Out:
#     isim   yas   maas
# 1   veli  16.0  150.0
# 2  kenan  17.0  240.0
# 3  murat  33.0  350.0
# 4   ayse   NaN  110.0
# 5  hilal  66.0  220.0

# %%
#veri setinin sütun isimlerini kontrol etmek isteyebiliriz.
veri.columns
# Out:
# Index(['isim', 'yas', 'maas'], dtype='object')

# %%
"""
info() ile nelere bakabiliriz:
1-sütun sayısı ve adları
2-veri tipleri
3-boş olmayan verilerin sayısı
4-bellek kullanımı
"""
veri.info()
"""
Örneğin veri setinde 6 satır
var ancak yaş satırı 5 satırdan oluşuyor
demek ki yas sütununda NaN değerler
vardır çıkarımını yapabiliriz.
"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   isim    6 non-null      object
#  1   yas     5 non-null      float64
#  2   maas    6 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 272.0+ bytes

# %%
#describe() : ile veri seti içerisine bulunan numeric feature'ların temel istatistiksel analizini yapabiliriz.
veri.describe()
# Out:
#              yas        maas
# count   5.000000    6.000000
# mean   29.400000  195.000000
# std    21.755459   94.815611
# min    15.000000  100.000000
# 25%    16.000000  120.000000
# 50%    17.000000  185.000000
# 75%    33.000000  235.000000
# max    66.000000  350.000000

# %%
veri["yas"]
# Out:
# 0    15.0
# 1    16.0
# 2    17.0
# 3    33.0
# 4     NaN
# 5    66.0
# Name: yas, dtype: float64

# %%
veri["yas"].describe()
# Out:
# count     5.000000
# mean     29.400000
# std      21.755459
# min      15.000000
# 25%      16.000000
# 50%      17.000000
# 75%      33.000000
# max      66.000000
# Name: yas, dtype: float64

# %%
veri["yas"].mean()
# Out:
# 29.4

# %%
#DataFrame içerisine yeni sütun ekleme
veri["sehir"] = ["istanbul", "ankara", "izmir", "bursa", "izmir", "istanbul"]
veri
# Out:
#     isim  yas   maas     sehir
# 0    ali   15  110.0  istanbul
# 1   veli   16  160.0    ankara
# 2  kenan   17  250.0     izmir
# 3  murat   33  360.0     bursa
# 4   ayse   45  120.0     izmir
# 5  hilal   66  230.0  istanbul

# %%
veri["maas_yüzde_20_zamli"] = veri["maas"] + 20*veri["maas"]/100
veri
# Out:
#     isim  yas   maas     sehir  maas_yüzde_20_zamli
# 0    ali   15  110.0  istanbul                132.0
# 1   veli   16  160.0    ankara                192.0
# 2  kenan   17  250.0     izmir                300.0
# 3  murat   33  360.0     bursa                432.0
# 4   ayse   45  120.0     izmir                144.0
# 5  hilal   66  230.0  istanbul                276.0

# %%
#loc: location kısaltmasından gelir, etiket tabanlı indexlemedir. Dilimler dahil edicidir.
veri.loc[: , "yas"] # : bütün satırlar, ["yas"] yas sütunu
# Out:
# 0    15
# 1    16
# 2    17
# 3    33
# 4    45
# 5    66
# Name: yas, dtype: int64

# %%
veri.loc[0:2, ["sehir"]] #0 1 2 satırlar
# Out:
#       sehir
# 0  istanbul
# 1    ankara
# 2     izmir

# %%
veri.loc[0:2, ["yas","maas","sehir"]] #yas maas sehir sütunlarından 0 1 2 . satırlar
# Out:
#    yas   maas     sehir
# 0   15  110.0  istanbul
# 1   16  160.0    ankara
# 2   17  250.0     izmir

# %%
veri.loc[0:2, 'yas':'sehir'] #yas sütunundan maas sütununa 0 1 2 satırlar
# Out:
#    yas   maas     sehir
# 0   15  110.0  istanbul
# 1   16  160.0    ankara
# 2   17  250.0     izmir

# %%
#iloc: tamsayı tabanlı indexlemey destekler. indisleme 0dan başlar. ancak dahil edici değildir.
veri.iloc[0:2,1] #0 ve 1. satırlar 1. sütun yani yas
# Out:
# 0    15
# 1    16
# Name: yas, dtype: int64

# %%
veri.iloc[[2,4],[1,2]] #2.ve 4.satır 1.ve 2.sütun
# Out:
#    yas   maas
# 2   17  250.0
# 4   45  120.0

# %%
veri.iloc[2:3,[1,2]]
# Out:
#    yas   maas
# 2   17  250.0

# %%
veri["maas2"] = veri["maas"] + 10
veri
# Out:
#     isim  yas   maas     sehir  maas_yüzde_20_zamli  maas2
# 0    ali   15  110.0  istanbul                132.0  120.0
# 1   veli   16  160.0    ankara                192.0  170.0
# 2  kenan   17  250.0     izmir                300.0  260.0
# 3  murat   33  360.0     bursa                432.0  370.0
# 4   ayse   45  120.0     izmir                144.0  130.0
# 5  hilal   66  230.0  istanbul                276.0  240.0

# %%
cols= veri.columns
cols
# Out:
# Index(['isim', 'yas', 'maas', 'sehir', 'maas_yüzde_20_zamli', 'maas2'], dtype='object')

# %%
#veri.columns tipi 'object'tir biz liste uygulamaları yapmak için(örneğin silme) onu tolist ile liste yaparız
cols= veri.columns.tolist()
cols
# Out:
# ['isim', 'yas', 'maas', 'sehir', 'maas_yüzde_20_zamli', 'maas2']

# %%
cols.remove("maas2")
cols
# Out:
# ['isim', 'yas', 'maas', 'sehir', 'maas_yüzde_20_zamli']

# %%
cols.remove("maas_yüzde_20_zamli")
cols
# Out:
# ['isim', 'yas', 'maas', 'sehir']

# %%
#maas2 column yas columndan önce eklemek için
cols.insert(1,"maas2")
cols
# Out:
# ['isim', 'maas2', 'yas', 'maas', 'sehir']

# %%
veri=veri[cols]
veri
# Out:
#     isim  maas2  yas   maas     sehir
# 0    ali  120.0   15  110.0  istanbul
# 1   veli  170.0   16  160.0    ankara
# 2  kenan  260.0   17  250.0     izmir
# 3  murat  370.0   33  360.0     bursa
# 4   ayse  130.0   45  120.0     izmir
# 5  hilal  240.0   66  230.0  istanbul

# %%
#ALIŞTIRMA
dictionary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "maas": [100.0, 150.0, 240.0, 350.0, 110.0, 220.0]}
veri=pd.DataFrame(dictionary)
veri
#murat	33

#45 110
#66 220

#veli 45
# Out:
#     isim  yas   maas
# 0    ali   15  100.0
# 1   veli   16  150.0
# 2  kenan   17  240.0
# 3  murat   33  350.0
# 4   ayse   45  110.0
# 5  hilal   66  220.0

# %%
#murat	33
veri.loc[3,"isim":"yas"]
veri.iloc[3:4,0:2]
# Out:
#     isim  yas
# 3  murat   33

# %%
#45 110
#66 220

veri.loc[4:5,"yas":"maas"]

veri.iloc[4:6 , 1:3]
# Out:
#    yas   maas
# 4   45  110.0
# 5   66  220.0

# %%
#veli 45
print(veri.loc[1,["isim"]],veri.loc[4,["yas"]])
print(veri.iloc[1,0],veri.iloc[4,1])
# Out:
# isim    veli
# Name: 1, dtype: object yas    45
# Name: 4, dtype: object
# veli 45

# %% [markdown]
# **Filtreleme**

# %%
dictionary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "sehir": ["izmir", "ankara", "konya", "ankara", "ankara","antalya"]}
veri=pd.DataFrame(dictionary)
veri
# Out:
#     isim  yas    sehir
# 0    ali   15    izmir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
filtre_1 = veri["yas"] > 22
filtre_1
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# Name: yas, dtype: bool

# %%
#22yasından buyuk olanları belirledik saha sonra bunu verisetine uyguladık
filtrelenmis_veri = veri[filtre_1]
filtrelenmis_veri
# Out:
#     isim  yas    sehir
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
#ankarada yaşayanlar
filtre_2 = veri["sehir"] == "ankara"
filtre_2
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# Name: sehir, dtype: bool

# %%
filtrelenmis_veri_2 = veri[filtre_2]
filtrelenmis_veri_2
# Out:
#     isim  yas   sehir
# 1   veli   16  ankara
# 3  murat   33  ankara
# 4   ayse   45  ankara

# %%
#22 yasindan büyük ve ankarada yaşayanlar
veri[filtre_1 & filtre_2]
# Out:
#     isim  yas   sehir
# 3  murat   33  ankara
# 4   ayse   45  ankara

# %%
filtre_3 = veri["isim"] == "ali"
veri[filtre_3]
# Out:
#   isim  yas  sehir
# 0  ali   15  izmir

# %%
#bitwise_and : x1 ve x2 girdilerini alır ve bu girdiler üzerinde bit düzeyinde AND işlemi uygular.
np.bitwise_and(veri["sehir"] =="ankara" , veri["yas"] > 22)
veri[np.bitwise_and(veri["sehir"] =="ankara" , veri["yas"] > 22)]
# Out:
#     isim  yas   sehir
# 3  murat   33  ankara
# 4   ayse   45  ankara

# %%
dictionary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "sehir": ["izmir", "ankara", "konya", "ankara", "ankara","antalya"]}
veri=pd.DataFrame(dictionary)
veri
"""
1) yeni sutun: maas sutunu ekle
2) yeni sutun: yas/maas orani sutunu ekle
3) yas/maas sutunu icin ortalamayi print ettir
4) ankarada yasayanlarin ortalama yasini bul
5) ankarada yasayanlarin icinden en yuksek maas alani bul
"""
# Out:
# '\n1) yeni sutun: maas sutunu ekle\n2) yeni sutun: yas/maas orani sutunu ekle\n3) yas/maas sutunu icin ortalamayi print ettir\n4) ankarada yasayanlarin ortalama yasini bul\n5) ankarada yasayanlarin icinden en yuksek maas alani bul\n'

# %%
# yeni sutun: maas sutunu ekle
veri["maas"] = [100, 200, 300, 400, 500, 600]
veri
# Out:
#     isim  yas    sehir  maas
# 0    ali   15    izmir   100
# 1   veli   16   ankara   200
# 2  kenan   17    konya   300
# 3  murat   33   ankara   400
# 4   ayse   45   ankara   500
# 5  hilal   66  antalya   600

# %%
#yeni sutun: yas/maas orani sutunu ekle
veri["yas_maas_orani"] = veri["yas"] / veri["maas"]
veri
# Out:
#     isim  yas    sehir  maas  yas_maas_orani
# 0    ali   15    izmir   100        0.150000
# 1   veli   16   ankara   200        0.080000
# 2  kenan   17    konya   300        0.056667
# 3  murat   33   ankara   400        0.082500
# 4   ayse   45   ankara   500        0.090000
# 5  hilal   66  antalya   600        0.110000

# %%
#yas/maas sutunu icin ortalamayi print ettir
veri["yas_maas_orani"].mean()
np.mean(veri["yas_maas_orani"])
# Out:
# 0.0948611111111111

# %%
veri["ulke"] = ["turkiye"]*len(veri)
veri
# Out:
#     isim  yas    sehir  maas  yas_maas_orani     ulke
# 0    ali   15    izmir   100        0.150000  turkiye
# 1   veli   16   ankara   200        0.080000  turkiye
# 2  kenan   17    konya   300        0.056667  turkiye
# 3  murat   33   ankara   400        0.082500  turkiye
# 4   ayse   45   ankara   500        0.090000  turkiye
# 5  hilal   66  antalya   600        0.110000  turkiye

# %%
#ankarada yasayanlarin ortalama yasini bul
ankarada_yasayanlar = veri[veri["sehir"] =="ankara"]
ankarada_yasayanlar
ankarada_yasayan_yas = ankarada_yasayanlar["yas"]
ankarada_yasayan_yas

ort_yas = np.mean(ankarada_yasayan_yas)
ort_yas
# Out:
# 31.333333333333332

# %%
#ankarada yasayanlarin icinden en yuksek maas alani bul
ankarada_yasayanlar_maas = ankarada_yasayanlar["maas"]
ankarada_yasayanlar_maas
maas = np.max (ankarada_yasayanlar_maas)
maas
# Out:
# 500

# %%
# maximum maasi alanin adini bulalim ( for döngüsü ile )
ankarada_yasayanlar


#indexleri resetledik çünkü 1 3 4 diye gidiyordu veri bozulmasın diye resetledik.
ankarada_yasayanlar.reset_index(drop=True, inplace=True)
ankarada_yasayanlar

max_maas = 0
max_isim = ""

for i in range (len(ankarada_yasayanlar)):
  if ankarada_yasayanlar["maas"][i] > max_maas:
    max_maas = ankarada_yasayanlar["maas"][i]
    max_isim = ankarada_yasayanlar["isim"][i]
print(max_isim)
# Out:
# ayse

# %%
ankarada_yasayanlar.loc[ankarada_yasayanlar["maas"].idxmax(), "isim"]
# Out:
# 'ayse'

# %% [markdown]
# **List** **Comprehansion** : **Liste** **Kavrama**
#
# Python'da mevcut bir listeden yeni bir liste oluşturmanın özlü bir yoludur.
#
#
# ```
# yeni_liste = [ifade for eleman in eski_liste if koşul]
# ```

# %%
import pandas as pd
import numpy as np

# %%
dictionary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "sehir": ["izmir", "ankara", "konya", "ankara", "ankara","antalya"]}
veri=pd.DataFrame(dictionary)
veri
# Out:
#     isim  yas    sehir
# 0    ali   15    izmir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
# insanlarin ortlama yasini bulalim
ortalama_yas = np.mean(veri["yas"])
print(f"ortalama yas : {ortalama_yas}")
# Out:
# ortalama yas : 32.0

# %%
 #bu yastan buyuk ve kucuk olanlari filtreleyelim
 yas_ort_filter = veri["yas"] > ortalama_yas
 yas_ort_filter
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# Name: yas, dtype: bool

# %%
# buyuk olanlara yeni bir feature olusturarak buyu, kucuk olanlara ise kucuk yazalım
#for ile gerçekleştireceğiz
veri_yas = veri.yas
veri_yas_mean = np.mean (veri_yas)

liste_yas_grubu =[]

for i in range(len(veri_yas)):
  dummy_veri_yas = veri_yas[i]
  if veri_yas_mean > dummy_veri_yas:
    liste_yas_grubu.append("kucuk")
  else:
    liste_yas_grubu.append("buyuk")

liste_yas_grubu

veri["yas_grubu" ] = liste_yas_grubu
veri
# Out:
#     isim  yas    sehir yas_grubu
# 0    ali   15    izmir     kucuk
# 1   veli   16   ankara     kucuk
# 2  kenan   17    konya     kucuk
# 3  murat   33   ankara     buyuk
# 4   ayse   45   ankara     buyuk
# 5  hilal   66  antalya     buyuk

# %%
# burada for ile gerçekleştirdiğimiz işlemi list Comprehansion ile yapalım
veri["yas_grubu_comp"] = ["kucuk" if veri_yas_mean > veri_yas[i] else "büyük" for i in range(len(veri_yas))]
veri
#
# Out:
#     isim  yas    sehir yas_grubu yas_grubu_comp
# 0    ali   15    izmir     kucuk          kucuk
# 1   veli   16   ankara     kucuk          kucuk
# 2  kenan   17    konya     kucuk          kucuk
# 3  murat   33   ankara     buyuk          büyük
# 4   ayse   45   ankara     buyuk          büyük
# 5  hilal   66  antalya     buyuk          büyük

# %%
veri["YAS_GRUBU_'"] = [ i.upper() for i in veri.yas_grubu_comp]
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu_comp YAS_GRUBU_'
# 0    ali   15    izmir     kucuk          kucuk       KUCUK
# 1   veli   16   ankara     kucuk          kucuk       KUCUK
# 2  kenan   17    konya     kucuk          kucuk       KUCUK
# 3  murat   33   ankara     buyuk          büyük       BÜYÜK
# 4   ayse   45   ankara     buyuk          büyük       BÜYÜK
# 5  hilal   66  antalya     buyuk          büyük       BÜYÜK

# %%
veri.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
# problem definition: tum satirlara bakalim eger ankarada yasayan varsa, yasini x 2 , else yas x 5
# new_yas sutun olusturalim
veri["new_yas"] = [veri.yas[i] *3  if veri.sehir[i]=="ankara" else veri.yas[i] *5 for i in range(len(veri))]
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu_comp YAS_GRUBU_'  new_yas
# 0    ali   15    izmir     kucuk          kucuk       KUCUK       75
# 1   veli   16   ankara     kucuk          kucuk       KUCUK       48
# 2  kenan   17    konya     kucuk          kucuk       KUCUK       85
# 3  murat   33   ankara     buyuk          büyük       BÜYÜK       99
# 4   ayse   45   ankara     buyuk          büyük       BÜYÜK      135
# 5  hilal   66  antalya     buyuk          büyük       BÜYÜK      330

# %%
def onYilSonrasi(age):
  output  = age +10
  return output

# %%
#apply ile for kullanıp satır satır dolaşmak yerine bütün sütunlara o işlemi uygular.
#apply default olarak axis=0  yani sütuna ekleme yapar
veri["yas_10_yil_sonra"] = veri.yas.apply(onYilSonrasi)
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu_comp YAS_GRUBU_'  new_yas  \
# 0    ali   15    izmir     kucuk          kucuk       KUCUK       75
# 1   veli   16   ankara     kucuk          kucuk       KUCUK       48
# 2  kenan   17    konya     kucuk          kucuk       KUCUK       85
# 3  murat   33   ankara     buyuk          büyük       BÜYÜK       99
# 4   ayse   45   ankara     buyuk          büyük       BÜYÜK      135
# 5  hilal   66  antalya     buyuk          büyük       BÜYÜK      330
#
#    yas_10_yil_sonra
# 0                25
# 1                26
# 2                27
# 3                43
# 4                55
# 5                76

# %%
def yasCarpim(df):
  if df.sehir=="ankara":
    return df.yas *2
  else:
    return df.yas *5

# %%
veri.apply(yasCarpim,axis=1)
#apply sütunu besler axis=1 yapınca satırı besler
# Out:
# 0     75
# 1     32
# 2     85
# 3     66
# 4     90
# 5    330
# dtype: int64

# %%
def yasCarpim(df):
  if df.sehir == "ankara":
    return df.yas*2
  elif df.sehir == "izmir":
    return df.yas *3
  else:
    return df.yas*5

# %%
veri.apply(yasCarpim, axis=1)
# Out:
# 0     45
# 1     32
# 2     85
# 3     66
# 4     90
# 5    330
# dtype: int64

# %%
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu_comp YAS_GRUBU_'  new_yas  \
# 0    ali   15    izmir     kucuk          kucuk       KUCUK       75
# 1   veli   16   ankara     kucuk          kucuk       KUCUK       48
# 2  kenan   17    konya     kucuk          kucuk       KUCUK       85
# 3  murat   33   ankara     buyuk          büyük       BÜYÜK       99
# 4   ayse   45   ankara     buyuk          büyük       BÜYÜK      135
# 5  hilal   66  antalya     buyuk          büyük       BÜYÜK      330
#
#    yas_10_yil_sonra
# 0                25
# 1                26
# 2                27
# 3                43
# 4                55
# 5                76

# %%
# dataframe de bulunan insanlarin isimlerinin uzunlugu == 5 ise yeni yasi 2 ile varpalim
# eger isim uzunlugu == 4 ise 3 ile carpalim else 4 ile carpalim

def isimUzunluk(df):
  if len(df.isim)==5:
    return df.yas*2
  elif len(df.isim)==4:
    return df.yas*3
  else:
    return df.yas*4
veri["new_yas_1"]=veri.apply(isimUzunluk,axis=1)
veri
#
# Out:
#     isim  yas    sehir yas_grubu yas_grubu_comp YAS_GRUBU_'  new_yas  \
# 0    ali   15    izmir     kucuk          kucuk       KUCUK       75
# 1   veli   16   ankara     kucuk          kucuk       KUCUK       48
# 2  kenan   17    konya     kucuk          kucuk       KUCUK       85
# 3  murat   33   ankara     buyuk          büyük       BÜYÜK       99
# 4   ayse   45   ankara     buyuk          büyük       BÜYÜK      135
# 5  hilal   66  antalya     buyuk          büyük       BÜYÜK      330
#
#    yas_10_yil_sonra  new_yas_1
# 0                25         60
# 1                26         48
# 2                27         34
# 3                43         66
# 4                55        135
# 5                76        132

# %% [markdown]
# **Birleştirme**

# %%
import pandas as pd
sozluk1 = {"isim": ["ali", "veli"],
           "yas": [15, 16]}
veri1 = pd.DataFrame(sozluk1)
veri1

sozluk2 = {"isim": ["murat", "ayse"],
           "yas": [32, 33]}
veri2 = pd.DataFrame(sozluk2)
veri2
# Out:
#     isim  yas
# 0  murat   32
# 1   ayse   33

# %%
#concat

veri_yatay = pd.concat([veri1,veri2],axis=1)
veri_yatay

veri_dikey= pd.concat([veri1,veri2],axis=0)

veri_dikey.reset_index(drop=True, inplace=True)
#reset yerine veri_dikey = pd.concat([veri1, veri3], axis = 0, ignore_index=True) de kullanabiliriz.
veri_dikey
# Out:
#     isim  yas
# 0    ali   15
# 1   veli   16
# 2  murat   32
# 3   ayse   33
